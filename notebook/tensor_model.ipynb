# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers import Rescaling, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)

# Data augmentation
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal_and_vertical"),
    keras.layers.RandomRotation(0.2),
])

# Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Create the model
num_classes = len(class_names)

model = keras.Sequential([
    data_augmentation,
    Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes)
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)

# Train the model
epochs = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)

# # Save the model as a TFLite file
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()

# with open('C:/test001/ttt/cnn_classifier/ml_model/model.tflite', 'wb') as f:
#     f.write(tflite_model)
# Out:
# Found 99891 files belonging to 10 classes.
# Using 79913 files for training.
# Found 99891 files belonging to 10 classes.
# Using 19978 files for validation.
# ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# c:\test001\ttt\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.5114 - loss: 1.4216 - val_accuracy: 0.7522 - val_loss: 0.7673 - learning_rate: 0.0010
# Epoch 2/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.7384 - loss: 0.7949 - val_accuracy: 0.7697 - val_loss: 0.7238 - learning_rate: 0.0010
# Epoch 3/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.7751 - loss: 0.7005 - val_accuracy: 0.8050 - val_loss: 0.6180 - learning_rate: 0.0010
# Epoch 4/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.7883 - loss: 0.6518 - val_accuracy: 0.8262 - val_loss: 0.5490 - learning_rate: 0.0010
# Epoch 5/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8045 - loss: 0.6115 - val_accuracy: 0.7941 - val_loss: 0.6685 - learning_rate: 0.0010
# Epoch 6/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8125 - loss: 0.5870 - val_accuracy: 0.8377 - val_loss: 0.5156 - learning_rate: 0.0010
# Epoch 7/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8191 - loss: 0.5701 - val_accuracy: 0.8374 - val_loss: 0.5218 - learning_rate: 0.0010
# Epoch 8/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8200 - loss: 0.5606 - val_accuracy: 0.8363 - val_loss: 0.5210 - learning_rate: 0.0010
# Epoch 9/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8237 - loss: 0.5541 - val_accuracy: 0.8626 - val_loss: 0.4477 - learning_rate: 0.0010
# Epoch 10/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8316 - loss: 0.5359 - val_accuracy: 0.8540 - val_loss: 0.4567 - learning_rate: 0.0010
# Epoch 11/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8350 - loss: 0.5238 - val_accuracy: 0.8513 - val_loss: 0.4884 - learning_rate: 0.0010
# Epoch 12/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8370 - loss: 0.5171 - val_accuracy: 0.8625 - val_loss: 0.4365 - learning_rate: 0.0010
# Epoch 13/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8376 - loss: 0.5162 - val_accuracy: 0.8474 - val_loss: 0.4757 - learning_rate: 0.0010
# Epoch 14/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8421 - loss: 0.4999 - val_accuracy: 0.8627 - val_loss: 0.4335 - learning_rate: 0.0010
# Epoch 15/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8415 - loss: 0.4995 - val_accuracy: 0.8712 - val_loss: 0.4189 - learning_rate: 0.0010
# Epoch 16/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8434 - loss: 0.5021 - val_accuracy: 0.8692 - val_loss: 0.4283 - learning_rate: 0.0010
# Epoch 17/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8457 - loss: 0.4877 - val_accuracy: 0.8652 - val_loss: 0.4261 - learning_rate: 0.0010
# Epoch 18/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8467 - loss: 0.4914 - val_accuracy: 0.8684 - val_loss: 0.4327 - learning_rate: 0.0010
# Epoch 19/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8559 - loss: 0.4647 - val_accuracy: 0.8824 - val_loss: 0.3807 - learning_rate: 2.0000e-04
# Epoch 20/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8616 - loss: 0.4464 - val_accuracy: 0.8817 - val_loss: 0.3742 - learning_rate: 2.0000e-04
# Epoch 21/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8627 - loss: 0.4385 - val_accuracy: 0.8849 - val_loss: 0.3736 - learning_rate: 2.0000e-04
# Epoch 22/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8655 - loss: 0.4321 - val_accuracy: 0.8871 - val_loss: 0.3689 - learning_rate: 2.0000e-04
# Epoch 23/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8652 - loss: 0.4309 - val_accuracy: 0.8820 - val_loss: 0.3745 - learning_rate: 2.0000e-04
# Epoch 24/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8652 - loss: 0.4287 - val_accuracy: 0.8862 - val_loss: 0.3691 - learning_rate: 2.0000e-04
# Epoch 25/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8660 - loss: 0.4235 - val_accuracy: 0.8889 - val_loss: 0.3611 - learning_rate: 2.0000e-04
# Epoch 26/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8663 - loss: 0.4280 - val_accuracy: 0.8865 - val_loss: 0.3617 - learning_rate: 2.0000e-04
# Epoch 27/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8662 - loss: 0.4224 - val_accuracy: 0.8899 - val_loss: 0.3588 - learning_rate: 2.0000e-04
# Epoch 28/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8662 - loss: 0.4220 - val_accuracy: 0.8904 - val_loss: 0.3568 - learning_rate: 2.0000e-04
# Epoch 29/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8676 - loss: 0.4157 - val_accuracy: 0.8894 - val_loss: 0.3618 - learning_rate: 2.0000e-04
# Epoch 30/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8689 - loss: 0.4263 - val_accuracy: 0.8906 - val_loss: 0.3543 - learning_rate: 2.0000e-04

# %%
# Save the model as a TFLite file
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('C:/test001/ttt/cnn_classifier/tensor_models/model001_86_0.4.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpwp5udf2r\assets
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpwp5udf2r\assets
# Saved artifact at 'C:\Users\Mind\AppData\Local\Temp\tmpwp5udf2r'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2153097277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153097278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153097280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153097281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153097279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153097280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092776400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092777168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092778896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092779280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092778128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092778512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092777744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092780048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092781392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092782160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092780432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092781008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092781584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092782928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092782352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153092783696: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers import Rescaling, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)

# Data augmentation
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal_and_vertical"),
    keras.layers.RandomRotation(0.2),
])

# Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Create the model
num_classes = len(class_names)

model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(num_classes)  # Ensure this matches the number of classes
])

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)

# Train the model
epochs = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Found 99891 files belonging to 10 classes.
# Using 79913 files for training.
# Found 99891 files belonging to 10 classes.
# Using 19978 files for validation.
# ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# c:\test001\ttt\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 392,906 (1.50 MB)
#  Trainable params: 391,946 (1.50 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - accuracy: 0.6797 - loss: 1.0476 - val_accuracy: 0.8930 - val_loss: 0.3463 - learning_rate: 0.0010
# Epoch 2/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8560 - loss: 0.4613 - val_accuracy: 0.8969 - val_loss: 0.3213 - learning_rate: 0.0010
# Epoch 3/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8809 - loss: 0.3798 - val_accuracy: 0.9213 - val_loss: 0.2575 - learning_rate: 0.0010
# Epoch 4/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8899 - loss: 0.3476 - val_accuracy: 0.9292 - val_loss: 0.2312 - learning_rate: 0.0010
# Epoch 5/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9000 - loss: 0.3198 - val_accuracy: 0.9307 - val_loss: 0.2251 - learning_rate: 0.0010
# Epoch 6/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9054 - loss: 0.3025 - val_accuracy: 0.9340 - val_loss: 0.2163 - learning_rate: 0.0010
# Epoch 7/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9101 - loss: 0.2865 - val_accuracy: 0.9324 - val_loss: 0.2222 - learning_rate: 0.0010
# Epoch 8/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9129 - loss: 0.2800 - val_accuracy: 0.9394 - val_loss: 0.2017 - learning_rate: 0.0010
# Epoch 9/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9134 - loss: 0.2785 - val_accuracy: 0.9395 - val_loss: 0.2010 - learning_rate: 0.0010
# Epoch 10/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - accuracy: 0.9167 - loss: 0.2657 - val_accuracy: 0.9409 - val_loss: 0.1971 - learning_rate: 0.0010
# Epoch 11/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.9208 - loss: 0.2539 - val_accuracy: 0.9405 - val_loss: 0.1931 - learning_rate: 0.0010
# Epoch 12/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.9200 - loss: 0.2516 - val_accuracy: 0.9409 - val_loss: 0.1963 - learning_rate: 0.0010
# Epoch 13/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - accuracy: 0.9242 - loss: 0.2431 - val_accuracy: 0.9425 - val_loss: 0.1918 - learning_rate: 0.0010
# Epoch 14/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 35s 14ms/step - accuracy: 0.9245 - loss: 0.2389 - val_accuracy: 0.9440 - val_loss: 0.1897 - learning_rate: 0.0010
# Epoch 15/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 29s 11ms/step - accuracy: 0.9239 - loss: 0.2443 - val_accuracy: 0.9458 - val_loss: 0.1820 - learning_rate: 0.0010
# Epoch 16/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - accuracy: 0.9237 - loss: 0.2409 - val_accuracy: 0.9452 - val_loss: 0.1851 - learning_rate: 0.0010
# Epoch 17/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - accuracy: 0.9260 - loss: 0.2313 - val_accuracy: 0.9452 - val_loss: 0.1865 - learning_rate: 0.0010
# Epoch 18/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - accuracy: 0.9288 - loss: 0.2271 - val_accuracy: 0.9450 - val_loss: 0.1831 - learning_rate: 0.0010
# Epoch 19/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - accuracy: 0.9342 - loss: 0.2131 - val_accuracy: 0.9472 - val_loss: 0.1757 - learning_rate: 2.0000e-04
# Epoch 20/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9343 - loss: 0.2084 - val_accuracy: 0.9478 - val_loss: 0.1765 - learning_rate: 2.0000e-04
# Epoch 21/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9348 - loss: 0.2026 - val_accuracy: 0.9482 - val_loss: 0.1759 - learning_rate: 2.0000e-04
# Epoch 22/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9366 - loss: 0.2010 - val_accuracy: 0.9481 - val_loss: 0.1751 - learning_rate: 2.0000e-04
# Epoch 23/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9371 - loss: 0.1967 - val_accuracy: 0.9487 - val_loss: 0.1741 - learning_rate: 2.0000e-04
# Epoch 24/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9375 - loss: 0.1955 - val_accuracy: 0.9484 - val_loss: 0.1735 - learning_rate: 2.0000e-04
# Epoch 25/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9381 - loss: 0.1934 - val_accuracy: 0.9488 - val_loss: 0.1739 - learning_rate: 2.0000e-04
# Epoch 26/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9357 - loss: 0.1979 - val_accuracy: 0.9502 - val_loss: 0.1728 - learning_rate: 2.0000e-04
# Epoch 27/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9378 - loss: 0.1945 - val_accuracy: 0.9500 - val_loss: 0.1719 - learning_rate: 2.0000e-04
# Epoch 28/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9398 - loss: 0.1884 - val_accuracy: 0.9490 - val_loss: 0.1741 - learning_rate: 2.0000e-04
# Epoch 29/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - accuracy: 0.9370 - loss: 0.1955 - val_accuracy: 0.9495 - val_loss: 0.1730 - learning_rate: 2.0000e-04
# Epoch 30/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9394 - loss: 0.1901 - val_accuracy: 0.9491 - val_loss: 0.1743 - learning_rate: 2.0000e-04

# %%
# Save the model as a TFLite file
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('C:/test001/ttt/cnn_classifier/tensor_models/model002_94_0.19.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpsq66ifmy\assets
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpsq66ifmy\assets
# Saved artifact at 'C:\Users\Mind\AppData\Local\Temp\tmpsq66ifmy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 3), dtype=tf.float32, name='keras_tensor_19')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2153213814224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213813072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213813648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213813264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213814032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213812880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213811344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213810768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213811728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213810960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213812112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213810576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213809040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213808464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213809424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213808656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213809808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213808272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213817488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213818064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213817104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213819792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213807888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213818256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213819024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2153213819984: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

class_names = ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']

# Load the TFLite model and allocate tensors
model_path = 'C:/test001/ttt/cnn_classifier/tensor_models/model003_88_0.36.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Define the image path
img_path = 'C:/test001/ttt/data/alarm_clock/image_22.png'

# Load and preprocess the image
img_height = 28
img_width = 28

def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(img_height, img_width))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Create a batch axis
    img_array = img_array # Normalize the image
    return img_array

img_array = load_and_preprocess_image(img_path)

# Set the tensor to point to the input data to be inferred
interpreter.set_tensor(input_details[0]['index'], img_array)

# Run the inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])
predicted_class = np.argmax(output_data, axis=1)
class_names[predicted_class[0]]
# Out:
# 'alarm_clock'

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Increase image size
img_height = 28
img_width = 28

# Load and prepare the data (adjust the data loading code accordingly)

# More extensive data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
])

# Use a pre-trained model as the base
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
base_model.trainable = False

# Create the model
model = models.Sequential([
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(num_classes)
])

# Compile with a lower learning rate
optimizer = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStooting(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# Train the model
epochs = 50
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)

# Fine-tune the model
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history_fine = model.fit(train_ds,
                         epochs=30,
                         validation_data=val_ds,
                         callbacks=[early_stopping, reduce_lr])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

num_classes = train_ds.class_names
print(num_classes)

# Enhanced data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),

])

# Create a more complex model
def create_model(num_classes):
    inputs = keras.Input(shape=(img_height, img_width, 3))
    x = data_augmentation(inputs)
    
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes)(x)
    
    return keras.Model(inputs, outputs)

model = create_model(len(num_classes))

# Compile with a lower learning rate and different optimizer
optimizer = keras.optimizers.Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# Train the model
epochs = 20  # Increased number of epochs
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Found 99891 files belonging to 10 classes.
# Using 79913 files for training.
# Found 99891 files belonging to 10 classes.
# Using 19978 files for validation.
# ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 28, 28, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 14, 14, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,287,754 (4.91 MB)
#  Trainable params: 1,284,938 (4.90 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# Epoch 1/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 137s 54ms/step - accuracy: 0.5125 - loss: 1.5619 - val_accuracy: 0.8584 - val_loss: 0.4554 - learning_rate: 0.0010
# Epoch 2/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 145s 58ms/step - accuracy: 0.8161 - loss: 0.5789 - val_accuracy: 0.8889 - val_loss: 0.3578 - learning_rate: 0.0010
# Epoch 3/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 240s 96ms/step - accuracy: 0.8467 - loss: 0.4894 - val_accuracy: 0.9089 - val_loss: 0.3012 - learning_rate: 0.0010
# Epoch 4/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 179s 72ms/step - accuracy: 0.8625 - loss: 0.4355 - val_accuracy: 0.8966 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 5/20
# 1979/2498 ━━━━━━━━━━━━━━━━━━━━ 43s 84ms/step - accuracy: 0.8692 - loss: 0.4093
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 88
#      86 # Train the model
#      87 epochs = 20  # Increased number of epochs
# ---> 88 history = model.fit(
#      89     train_ds,
#      90     validation_data=val_ds,
#      91     epochs=epochs,
#      92     callbacks=[early_stopping, reduce_lr]
#      93 )
#
# File c:\test001\ttt\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\test001\ttt\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\test001\ttt\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#with normalize 4.9mb model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

# Function to normalize and augment data
def preprocess_data(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    return image, label

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

num_classes = train_ds.class_names
num_classes = len(class_names)
print("Number of classes:", num_classes)
print("Class names:", class_names)
print(num_classes)

# Apply normalization
train_ds = train_ds.map(preprocess_data)
val_ds = val_ds.map(preprocess_data)

# Enhanced data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# Create a more complex model
def create_model(num_classes):
    inputs = keras.Input(shape=(img_height, img_width, 3))
    x = layers.Rescaling(1./255)(inputs)
    x = data_augmentation(inputs)
    
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes)(x)
    
    return keras.Model(inputs, outputs)

model = create_model(num_classes)

# Compile with a lower learning rate and different optimizer
optimizer = keras.optimizers.Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# Train the model
epochs = 20
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Found 99891 files belonging to 10 classes.
# Using 79913 files for training.
# Found 99891 files belonging to 10 classes.
# Using 19978 files for validation.
# Number of classes: 10
# Class names: ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# 10
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 28, 28, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 14, 14, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_31          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,287,754 (4.91 MB)
#  Trainable params: 1,284,938 (4.90 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# Epoch 1/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 207s 82ms/step - accuracy: 0.5095 - loss: 1.5660 - val_accuracy: 0.8673 - val_loss: 0.4326 - learning_rate: 0.0010
# Epoch 2/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 211s 84ms/step - accuracy: 0.8167 - loss: 0.5762 - val_accuracy: 0.8684 - val_loss: 0.4332 - learning_rate: 0.0010
# Epoch 3/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 216s 87ms/step - accuracy: 0.8468 - loss: 0.4844 - val_accuracy: 0.9028 - val_loss: 0.3224 - learning_rate: 0.0010
# Epoch 4/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 137s 55ms/step - accuracy: 0.8636 - loss: 0.4370 - val_accuracy: 0.9049 - val_loss: 0.3141 - learning_rate: 0.0010
# Epoch 5/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 143s 57ms/step - accuracy: 0.8749 - loss: 0.4000 - val_accuracy: 0.9065 - val_loss: 0.3057 - learning_rate: 0.0010
# Epoch 6/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 223s 89ms/step - accuracy: 0.8817 - loss: 0.3776 - val_accuracy: 0.9121 - val_loss: 0.2890 - learning_rate: 0.0010
# Epoch 7/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 139s 56ms/step - accuracy: 0.8879 - loss: 0.3610 - val_accuracy: 0.9137 - val_loss: 0.2864 - learning_rate: 0.0010
# Epoch 8/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 134s 54ms/step - accuracy: 0.8924 - loss: 0.3470 - val_accuracy: 0.9163 - val_loss: 0.2626 - learning_rate: 0.0010
# Epoch 9/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 139s 55ms/step - accuracy: 0.8953 - loss: 0.3352 - val_accuracy: 0.9296 - val_loss: 0.2350 - learning_rate: 0.0010
# Epoch 10/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 139s 56ms/step - accuracy: 0.8994 - loss: 0.3260 - val_accuracy: 0.9257 - val_loss: 0.2413 - learning_rate: 0.0010
# Epoch 11/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 143s 57ms/step - accuracy: 0.9037 - loss: 0.3109 - val_accuracy: 0.9253 - val_loss: 0.2452 - learning_rate: 0.0010
# Epoch 12/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 138s 55ms/step - accuracy: 0.9035 - loss: 0.3092 - val_accuracy: 0.9279 - val_loss: 0.2441 - learning_rate: 0.0010
# Epoch 13/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 196s 78ms/step - accuracy: 0.9076 - loss: 0.2999 - val_accuracy: 0.9309 - val_loss: 0.2290 - learning_rate: 0.0010
# Epoch 14/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 240s 96ms/step - accuracy: 0.9089 - loss: 0.2943 - val_accuracy: 0.9287 - val_loss: 0.2333 - learning_rate: 0.0010
# Epoch 15/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 260s 104ms/step - accuracy: 0.9099 - loss: 0.2935 - val_accuracy: 0.9334 - val_loss: 0.2249 - learning_rate: 0.0010
# Epoch 16/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 253s 101ms/step - accuracy: 0.9114 - loss: 0.2869 - val_accuracy: 0.9360 - val_loss: 0.2140 - learning_rate: 0.0010
# Epoch 17/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 252s 101ms/step - accuracy: 0.9155 - loss: 0.2766 - val_accuracy: 0.9213 - val_loss: 0.2515 - learning_rate: 0.0010
# Epoch 18/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 251s 100ms/step - accuracy: 0.9139 - loss: 0.2785 - val_accuracy: 0.9313 - val_loss: 0.2257 - learning_rate: 0.0010
# Epoch 19/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 162s 65ms/step - accuracy: 0.9173 - loss: 0.2728 - val_accuracy: 0.9380 - val_loss: 0.2102 - learning_rate: 0.0010
# Epoch 20/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 198s 79ms/step - accuracy: 0.9158 - loss: 0.2731 - val_accuracy: 0.9376 - val_loss: 0.2076 - learning_rate: 0.0010

# %%
# Save the model as a TFLite file
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('C:/test001/ttt/cnn_classifier/tensor_models/model004_91_0.27.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpz9sdfkuv\assets
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpz9sdfkuv\assets
# Saved artifact at 'C:\Users\Mind\AppData\Local\Temp\tmpz9sdfkuv'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 3), dtype=tf.float32, name='keras_tensor_107')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2287450476944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450475216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450474640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450475408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450477136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450476176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450486160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450486736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450474256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450486544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450474448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450486928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287450487312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712223888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712224272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712223696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712223312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712224080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712225616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712226192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712225232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712226000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712224848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712226384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712227152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712228880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712228304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712228688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712226768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712229072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712230608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712231184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712230224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712230992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712229840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712231376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712232144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712233872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712233296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712233680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712231760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712234064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712234832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287712236560: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
#with normalize 1.5mb model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

# Load and normalize the data
def preprocess_data(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    return image, label

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

num_classes = train_ds.class_names
print("Number of classes:", num_classes)
print("Class names:", class_names)
print(num_classes)

# Apply normalization
train_ds = train_ds.map(preprocess_data)
val_ds = val_ds.map(preprocess_data)

# Enhanced data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)


# Create the model
num_classes = len(class_names)

model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    data_augmentation,
    
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(num_classes)  # Ensure this matches the number of classes
])

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.05, patience=5, min_lr=0.00001)

# Train the model
epochs = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Found 99891 files belonging to 10 classes.
# Using 79913 files for training.
# Found 99891 files belonging to 10 classes.
# Using 19978 files for validation.
# Number of classes: ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# Class names: ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_7 (Rescaling)         │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_17 (Sequential)      │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_54 (Conv2D)              │ (None, 28, 28, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_65          │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_55 (Conv2D)              │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_66          │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_56 (Conv2D)              │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_67          │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_68          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 392,906 (1.50 MB)
#  Trainable params: 391,946 (1.50 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - accuracy: 0.3889 - loss: 1.8387 - val_accuracy: 0.6907 - val_loss: 0.9150 - learning_rate: 0.0010
# Epoch 2/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.6375 - loss: 1.0659 - val_accuracy: 0.7350 - val_loss: 0.7816 - learning_rate: 0.0010
# Epoch 3/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.7091 - loss: 0.8595 - val_accuracy: 0.7665 - val_loss: 0.7164 - learning_rate: 0.0010
# Epoch 4/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.7435 - loss: 0.7708 - val_accuracy: 0.8229 - val_loss: 0.5358 - learning_rate: 0.0010
# Epoch 5/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.7588 - loss: 0.7209 - val_accuracy: 0.5414 - val_loss: 1.7210 - learning_rate: 0.0010
# Epoch 6/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.7696 - loss: 0.7015 - val_accuracy: 0.5658 - val_loss: 2.1152 - learning_rate: 0.0010
# Epoch 7/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.7757 - loss: 0.6794 - val_accuracy: 0.1739 - val_loss: 7.1196 - learning_rate: 0.0010
# Epoch 8/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.7826 - loss: 0.6545 - val_accuracy: 0.4031 - val_loss: 2.2401 - learning_rate: 0.0010
# Epoch 9/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.7939 - loss: 0.6352 - val_accuracy: 0.5337 - val_loss: 1.6292 - learning_rate: 0.0010
# Epoch 10/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.7960 - loss: 0.6231 - val_accuracy: 0.8729 - val_loss: 0.4072 - learning_rate: 5.0000e-05
# Epoch 11/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 29s 11ms/step - accuracy: 0.7994 - loss: 0.6100 - val_accuracy: 0.8762 - val_loss: 0.4001 - learning_rate: 5.0000e-05
# Epoch 12/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 33s 13ms/step - accuracy: 0.8033 - loss: 0.6060 - val_accuracy: 0.8696 - val_loss: 0.4082 - learning_rate: 5.0000e-05
# Epoch 13/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8075 - loss: 0.5940 - val_accuracy: 0.8716 - val_loss: 0.4002 - learning_rate: 5.0000e-05
# Epoch 14/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8076 - loss: 0.5933 - val_accuracy: 0.8735 - val_loss: 0.4025 - learning_rate: 5.0000e-05
# Epoch 15/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8082 - loss: 0.5881 - val_accuracy: 0.8750 - val_loss: 0.3926 - learning_rate: 5.0000e-05
# Epoch 16/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8103 - loss: 0.5867 - val_accuracy: 0.8779 - val_loss: 0.3915 - learning_rate: 5.0000e-05
# Epoch 17/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8111 - loss: 0.5853 - val_accuracy: 0.8816 - val_loss: 0.3849 - learning_rate: 5.0000e-05
# Epoch 18/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8103 - loss: 0.5792 - val_accuracy: 0.8773 - val_loss: 0.3843 - learning_rate: 5.0000e-05
# Epoch 19/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8116 - loss: 0.5795 - val_accuracy: 0.8755 - val_loss: 0.3931 - learning_rate: 5.0000e-05
# Epoch 20/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8143 - loss: 0.5709 - val_accuracy: 0.8568 - val_loss: 0.4349 - learning_rate: 5.0000e-05
# Epoch 21/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8136 - loss: 0.5732 - val_accuracy: 0.8706 - val_loss: 0.4085 - learning_rate: 5.0000e-05
# Epoch 22/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8156 - loss: 0.5667 - val_accuracy: 0.8723 - val_loss: 0.4005 - learning_rate: 5.0000e-05
# Epoch 23/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8160 - loss: 0.5673 - val_accuracy: 0.8839 - val_loss: 0.3707 - learning_rate: 5.0000e-05
# Epoch 24/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - accuracy: 0.8156 - loss: 0.5678 - val_accuracy: 0.8831 - val_loss: 0.3685 - learning_rate: 5.0000e-05
# Epoch 25/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.8165 - loss: 0.5652 - val_accuracy: 0.8869 - val_loss: 0.3611 - learning_rate: 5.0000e-05
# Epoch 26/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8180 - loss: 0.5636 - val_accuracy: 0.8769 - val_loss: 0.3915 - learning_rate: 5.0000e-05
# Epoch 27/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 27s 11ms/step - accuracy: 0.8172 - loss: 0.5644 - val_accuracy: 0.8778 - val_loss: 0.3863 - learning_rate: 5.0000e-05
# Epoch 28/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8200 - loss: 0.5554 - val_accuracy: 0.8826 - val_loss: 0.3695 - learning_rate: 5.0000e-05
# Epoch 29/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 27s 11ms/step - accuracy: 0.8173 - loss: 0.5627 - val_accuracy: 0.8781 - val_loss: 0.3847 - learning_rate: 5.0000e-05
# Epoch 30/30
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.8176 - loss: 0.5584 - val_accuracy: 0.8872 - val_loss: 0.3647 - learning_rate: 5.0000e-05

# %%
Epoch 10/30
2498/2498 ━━━━━━━━━━━━━━━━━━━  40s 16ms/step - accuracy: 0.8059 - loss: 0.5940 - val_accuracy: 0.2604 - val_loss: 3.8598 - learning_rate: 0.0010

# %%
# Save the model as a TFLite file
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('C:/test001/ttt/cnn_classifier/tensor_models/model_norm_simple_81_0.55.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpdpmq6quu\assets
# INFO:tensorflow:Assets written to: C:\Users\Mind\AppData\Local\Temp\tmpdpmq6quu\assets
# Saved artifact at 'C:\Users\Mind\AppData\Local\Temp\tmpdpmq6quu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 3), dtype=tf.float32, name='keras_tensor_282')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2287710577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452964816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452965200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452964624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452964240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452965008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452966544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452967120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452966160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452966928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452965776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452967312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452968464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452969424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452969616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452969232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452968848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452968080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452971536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452970576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452971344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452970192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452971728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2287452973840: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

class_names = ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']

# Load the TFLite model and allocate tensors
model_path = 'C:/test001/ttt/cnn_classifier/tensor_models/model004_97_0.08_norm.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Define the image path
img_path_folder = 'C:/test001/ttt/data/bed_sample'

# Load and preprocess the image
img_height = 28
img_width = 28

def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(img_height, img_width))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Create a batch axis
    img_array = img_array/255 # Normalize the image/255
    return img_array

img_array = load_and_preprocess_image(img_path)

# Set the tensor to point to the input data to be inferred
interpreter.set_tensor(input_details[0]['index'], img_array)

# Run the inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])
predicted_class = np.argmax(output_data, axis=1)
class_names[predicted_class[0]]
# Out:
# 'bat'

# %%
ImageClassifierWriter = image_classifier.MetadataWriter
_MODEL_PATH = 'C:/test001/ttt/cnn_classifier/ml_model/ios_model.tflite'
# Task Library expects label files that are in the same format as the one below.
_LABEL_FILE = 'C:/test001/ttt/cnn_classifier/notebook/label.txt'
_SAVE_TO_PATH = 'C:/test001/ttt/cnn_classifier/ml_model/model_with_metadata02.tflite'

_INPUT_NORM_MEAN = 0.0
_INPUT_NORM_STD = 1.0

# Create the metadata writer.
writer = ImageClassifierWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by the metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ImageClassifierWriter = image_classifier.MetadataWriter
#       2 _MODEL_PATH = 'C:/test001/ttt/cnn_classifier/ml_model/ios_model.tflite'
#       3 # Task Library expects label files that are in the same format as the one below.
#
# NameError: name 'image_classifier' is not defined

# %%
#C:\Users\Mind\3.7.ipynb

# %%
##most accurate 94%
####################################################################################
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers import Rescaling, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)

# Data augmentation
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal_and_vertical"),
    keras.layers.RandomRotation(0.2),
])

# Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Create the model
num_classes = len(class_names)

model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(num_classes)  # Ensure this matches the number of classes
])

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)

# Train the model
epochs = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)

# %%
#with normalize 4.9mb model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the data
data_dir = 'C:/test001/ttt/data'
batch_size = 32
img_height = 28
img_width = 28

# Function to normalize and augment data
def preprocess_data(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    return image, label

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

num_classes = train_ds.class_names
num_classes = len(class_names)
print("Number of classes:", num_classes)
print("Class names:", class_names)
print(num_classes)

# Apply normalization
train_ds = train_ds.map(preprocess_data)
val_ds = val_ds.map(preprocess_data)

# Enhanced data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# Create a more complex model
def create_model(num_classes):
    inputs = keras.Input(shape=(img_height, img_width, 3))
    x = layers.Rescaling(1./255)(inputs)
    
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes)(x)
    
    return keras.Model(inputs, outputs)

model = create_model(num_classes)

# Compile with a lower learning rate and different optimizer
optimizer = keras.optimizers.Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# Train the model
epochs = 20
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Found 99891 files belonging to 10 classes.
# Using 79913 files for training.
# Found 99891 files belonging to 10 classes.
# Using 19978 files for validation.
# Number of classes: 10
# Class names: ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']
# 10
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_24 (InputLayer)     │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_8 (Rescaling)         │ (None, 28, 28, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_57 (Conv2D)              │ (None, 28, 28, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_69          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_58 (Conv2D)              │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_70          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_59 (Conv2D)              │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_71          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_60 (Conv2D)              │ (None, 14, 14, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_72          │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_61 (Conv2D)              │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_62 (Conv2D)              │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_74          │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_7      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_75          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,287,754 (4.91 MB)
#  Trainable params: 1,284,938 (4.90 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# Epoch 1/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 136s 53ms/step - accuracy: 0.6930 - loss: 1.0374 - val_accuracy: 0.9013 - val_loss: 0.3233 - learning_rate: 0.0010
# Epoch 2/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 219s 87ms/step - accuracy: 0.8963 - loss: 0.3435 - val_accuracy: 0.9311 - val_loss: 0.2325 - learning_rate: 0.0010
# Epoch 3/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 198s 79ms/step - accuracy: 0.9117 - loss: 0.2901 - val_accuracy: 0.9345 - val_loss: 0.2240 - learning_rate: 0.0010
# Epoch 4/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 185s 74ms/step - accuracy: 0.9211 - loss: 0.2588 - val_accuracy: 0.9456 - val_loss: 0.1884 - learning_rate: 0.0010
# Epoch 5/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 139s 56ms/step - accuracy: 0.9300 - loss: 0.2310 - val_accuracy: 0.9341 - val_loss: 0.2208 - learning_rate: 0.0010
# Epoch 6/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 141s 56ms/step - accuracy: 0.9347 - loss: 0.2136 - val_accuracy: 0.9418 - val_loss: 0.1975 - learning_rate: 0.0010
# Epoch 7/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 160s 64ms/step - accuracy: 0.9399 - loss: 0.1976 - val_accuracy: 0.9514 - val_loss: 0.1646 - learning_rate: 0.0010
# Epoch 8/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 136s 54ms/step - accuracy: 0.9422 - loss: 0.1886 - val_accuracy: 0.9500 - val_loss: 0.1648 - learning_rate: 0.0010
# Epoch 9/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 137s 55ms/step - accuracy: 0.9475 - loss: 0.1744 - val_accuracy: 0.1000 - val_loss: 3.6795 - learning_rate: 0.0010
# Epoch 10/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 136s 54ms/step - accuracy: 0.9495 - loss: 0.1647 - val_accuracy: 0.9323 - val_loss: 0.2148 - learning_rate: 0.0010
# Epoch 11/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 137s 55ms/step - accuracy: 0.9525 - loss: 0.1537 - val_accuracy: 0.9266 - val_loss: 0.2509 - learning_rate: 0.0010
# Epoch 12/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 138s 55ms/step - accuracy: 0.9538 - loss: 0.1488 - val_accuracy: 0.6406 - val_loss: 1.3215 - learning_rate: 0.0010
# Epoch 13/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 172s 69ms/step - accuracy: 0.9600 - loss: 0.1304 - val_accuracy: 0.9586 - val_loss: 0.1496 - learning_rate: 2.0000e-04
# Epoch 14/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 216s 87ms/step - accuracy: 0.9642 - loss: 0.1134 - val_accuracy: 0.9473 - val_loss: 0.1898 - learning_rate: 2.0000e-04
# Epoch 15/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 139s 56ms/step - accuracy: 0.9666 - loss: 0.1072 - val_accuracy: 0.9578 - val_loss: 0.1584 - learning_rate: 2.0000e-04
# Epoch 16/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 197s 79ms/step - accuracy: 0.9681 - loss: 0.1012 - val_accuracy: 0.7302 - val_loss: 0.8982 - learning_rate: 2.0000e-04
# Epoch 17/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 172s 69ms/step - accuracy: 0.9707 - loss: 0.0921 - val_accuracy: 0.9587 - val_loss: 0.1582 - learning_rate: 2.0000e-04
# Epoch 18/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 197s 79ms/step - accuracy: 0.9709 - loss: 0.0916 - val_accuracy: 0.9589 - val_loss: 0.1573 - learning_rate: 2.0000e-04
# Epoch 19/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 236s 94ms/step - accuracy: 0.9734 - loss: 0.0814 - val_accuracy: 0.9599 - val_loss: 0.1573 - learning_rate: 4.0000e-05
# Epoch 20/20
# 2498/2498 ━━━━━━━━━━━━━━━━━━━━ 246s 98ms/step - accuracy: 0.9735 - loss: 0.0828 - val_accuracy: 0.9606 - val_loss: 0.1559 - learning_rate: 4.0000e-05

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import os

class_names = ['airplane', 'alarm_clock', 'ant', 'apple', 'basketball', 'bat', 'bathtub', 'bed', 'book', 'cycle']

# Load the TFLite model and allocate tensors
model_path = 'C:/test001/ttt/cnn_classifier/tensor_models/model004_97_0.08_norm.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Define the image path folder
img_path_folder = 'C:/test001/ttt/sample_test_data/bed_sample'

# Image dimensions
img_height = 28
img_width = 28

def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(img_height, img_width))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Create a batch axis
    img_array = img_array / 255.0  # Normalize the image
    return img_array

# List to store names of images not classified as 'bed'
not_bed_images = []

# Iterate through all files in the directory
for img_filename in os.listdir(img_path_folder):
    img_path = os.path.join(img_path_folder, img_filename)
    
    if not img_filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        continue  # Skip non-image files

    # Load and preprocess the image
    img_array = load_and_preprocess_image(img_path)

    # Set the tensor to point to the input data to be inferred
    interpreter.set_tensor(input_details[0]['index'], img_array)

    # Run the inference
    interpreter.invoke()

    # Get the output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])
    predicted_class = np.argmax(output_data, axis=1)
    predicted_label = class_names[predicted_class[0]]
    
    # Store image name if it's not classified as 'bed'
    if predicted_label != 'bed':
        not_bed_images.append(img_filename)
        not_bed_images.append(predicted_label)

# Print out the list of images not classified as 'bed'
print("Images not classified as 'apple':")
for img_name in not_bed_images:
    print(img_name)
# Out:
# Images not classified as 'apple':
# image_101637.png
# bathtub
# image_101706.png
# bathtub
# image_104675.png
# book
# image_106111.png
# ant
# image_107177.png
# book
# image_107490.png
# ant
# image_111069.png
# bat
# image_112698.png
# book
# image_11806.png
# alarm_clock
# image_11899.png
# book
# image_13762.png
# bathtub
# image_21138.png
# book
# image_25518.png
# cycle
# image_27401.png
# ant
# image_29958.png
# bathtub
# image_42077.png
# ant
# image_42376.png
# ant
# image_42880.png
# bathtub
# image_47626.png
# ant
# image_48065.png
# ant
# image_49345.png
# bathtub
# image_52391.png
# airplane
# image_66812.png
# bathtub
# image_68677.png
# bathtub
# image_69996.png
# bathtub
# image_72553.png
# airplane
# image_73745.png
# ant
# image_74857.png
# bathtub
# image_76059.png
# ant
# image_80451.png
# book
# image_80477.png
# bathtub
# image_81108.png
# alarm_clock
# image_83514.png
# ant
# image_84328.png
# apple
# image_92707.png
# bat
# image_94858.png
# bathtub
# image_97386.png
# bathtub
# image_97986.png
# alarm_clock
# image_99316.png
# book

# %%
len(not_bed_images)#/2
# Out:
# 39

# %%
not_bed_images[:20]
# Out:
# ['bathtub',
#  'bathtub',
#  'book',
#  'ant',
#  'book',
#  'ant',
#  'bat',
#  'book',
#  'alarm_clock',
#  'book',
#  'bathtub',
#  'book',
#  'cycle',
#  'ant',
#  'bathtub',
#  'ant',
#  'ant',
#  'bathtub',
#  'ant',
#  'ant']

# %%
(39/1000)*100
# Out:
# 3.9
